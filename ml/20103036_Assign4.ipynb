# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
    return np.exp(x) / (1 + np.exp(x))

# %%
df = pd.read_csv("./songs.csv")
df.head()
# Out:
#    year                           songtitle         artistname  \
# 0  2010  This Is the House That Doubt Built  A Day to Remember
# 1  2010                     Sticks & Bricks  A Day to Remember
# 2  2010                          All I Want  A Day to Remember
# 3  2010                    It's Complicated  A Day to Remember
# 4  2010                           2nd Sucks  A Day to Remember
#
#                songID            artistID  timesignature  \
# 0  SOBGGAB12C5664F054  AROBSHL1187B9AFB01              3
# 1  SOPAQHU1315CD47F31  AROBSHL1187B9AFB01              4
# 2  SOOIZOU1376E7C6386  AROBSHL1187B9AFB01              4
# 3  SODRYWD1315CD49DBE  AROBSHL1187B9AFB01              4
# 4  SOICMQB1315CD46EE3  AROBSHL1187B9AFB01              4
#
#    timesignature_confidence  loudness    tempo  tempo_confidence  ...  \
# 0                     0.853    -4.262   91.525             0.953  ...
# 1                     1.000    -4.051  140.048             0.921  ...
# ...

# %%
df = df.select_dtypes(include=np.number)
df.head()
# Out:
#    year  timesignature  timesignature_confidence  loudness    tempo  \
# 0  2010              3                     0.853    -4.262   91.525
# 1  2010              4                     1.000    -4.051  140.048
# 2  2010              4                     1.000    -3.571  160.512
# 3  2010              4                     1.000    -3.815   97.525
# 4  2010              4                     0.788    -4.707  140.053
#
#    tempo_confidence  key  key_confidence    energy  pitch  ...  timbre_7_max  \
# 0             0.953   11           0.453  0.966656  0.024  ...        82.475
# 1             0.921   10           0.469  0.984710  0.025  ...       106.918
# 2             0.489    2           0.209  0.989900  0.026  ...        80.621
# 3             0.794    1           0.632  0.939207  0.013  ...        96.675
# 4             0.286    6           0.483  0.987738  0.063  ...       110.332
#
#    timbre_8_min  timbre_8_max  timbre_9_min  timbre_9_max  timbre_10_min  \
# ...

# %%
# Spliting dataframe according to year (< 2010 = training, >= 2010 testing)
TRAIN = df[df['year'] < 2010]
TEST = df[df['year'] >= 2010]

# %%
x_train = TRAIN.loc[:, TRAIN.columns != 'Top10']
y_train = TRAIN.loc[:, TRAIN.columns == 'Top10']

x_test = TEST.loc[:, TEST.columns != 'Top10']
y_test = TEST.loc[:, TEST.columns == 'Top10']

# %%
# Checking if there are any missing values
print(x_train.isnull().sum().all())
print(x_test.isnull().sum().all())
# Out:
# False
# False

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()
clf.fit(x_train, y_train)
# Out:
# C:\Users\ISHWARENDRA\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\ISHWARENDRA\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()
